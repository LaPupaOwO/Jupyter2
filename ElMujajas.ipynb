# %% [markdown]
# # 🦖 EXPEDICIÓN PALEONTOLÓGICA 🦕
#
# ---
#
# ## 🏛️ Clasificación del Reino de los Terribles Lagartos
# Aquí tienes una lista organizada por colores según su tipo:
#
# * <font color="#FF5733">**CARNÍVOROS (Depredadores):**</font> Poseían dientes afilados y garras para cazar.
# * <font color="#2ECC71">**HERBÍVOROS (Gigantes):**</font> Alimentados de plantas, algunos medían más que un edificio.
# * <font color="#3498DB">**AÉREOS/ACUÁTICOS:**</font> Dominaban los cielos y los océanos profundos.
#
# ---
#
# ## 📊 Tabla de Comparación de Especies
# | Nombre | Periodo | Dieta | Peligro |
# | :--- | :--- | :--- | :--- |
# | **Tyrannosaurus Rex** | Cretácico | 🥩 Carnívoro | 🔴🔴🔴 |
# | **Brachiosaurus** | Jurásico | 🌿 Herbívoro | 🟡⚪⚪ |
# | **Triceratops** | Cretácico | 🌿 Herbívoro | 🟠🟠⚪ |
# | **Velociraptor** | Campaniense | 🥩 Carnívoro | 🔴🔴⚪ |
#
# ---
#
# ## 💡 Datos que no sabías
# > "El periodo **Jurásico** no fue el más importante para el T-Rex; él vivió realmente en el **Cretácico**."
#
# ---
#
# ### 🛠️ Herramientas de Análisis (Código Python)
# Crea una celda de código abajo para ejecutar este análisis:
#
# ```python
# dinos = ["T-Rex", "Velociraptor", "Triceratops"]
# for d in dinos:
#     print(f"✅ Analizando ADN de: {d} ... ¡Carga completa!")

# %%
print("Hola, este es mi documento en mi propio JupyterLite")
import math
print(f"La raíz cuadrada de 144 es {math.sqrt(144)}")
# Out:
# Hola, este es mi documento en mi propio JupyterLite
# La raíz cuadrada de 144 es 12.0
